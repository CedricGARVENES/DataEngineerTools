# %% [markdown]
# # Consignes
#
# Intégrer le fichier USvideos.csv qui représente un ensemble de 8000 vidéos Youtube.
#
# Merger le fichier US_category_id.json pour récupérer le nom des catégories. Il conviendra de bien spécifier l'ID du document.
#
#
# # Questions
# - 1) Récupérer toutes les vidéos de la chaîne Apple.
# - 2) Compter le nombre de catégories différentes
# - 3) Si vous ne l'avez pas déjà fait, découper les tags en listes et mettre à jour les tags de chacun des documents avec une requête update.
# - 4) Récupérer les vidéos les plus vues.
# - 5) Compter le nombre moyen de vues en fonction de la catégorie.
# - 6) Récupérer les chaines Youtube avec la plus grande moyenne de likes.

# %%
import pandas as pd
from pymongo import MongoClient

# %%
client = MongoClient("mongo")
database = client['exercices']
collection = database['youtube']

# %%
df_youtube = pd.read_csv("./data/USvideos.csv")
df_youtube.head(2)
# Out:
#       video_id                                              title  \
# 0  XpVt6Z1Gjjo  1 YEAR OF VLOGGING -- HOW LOGAN PAUL CHANGED Y...
# 1  K4wEI5zhHB0            iPhone X — Introducing iPhone X — Apple
#
#       channel_title  category_id  \
# 0  Logan Paul Vlogs           24
# 1             Apple           28
#
#                                                 tags    views   likes  \
# 0  logan paul vlog|logan paul|logan|paul|olympics...  4394029  320053
# 1  Apple|iPhone 10|iPhone Ten|iPhone|Portrait Lig...  7860119  185853
#
#    dislikes  comment_total                                  thumbnail_link  \
# 0      5931          46245  https://i.ytimg.com/vi/XpVt6Z1Gjjo/default.jpg
# 1     26679              0  https://i.ytimg.com/vi/K4wEI5zhHB0/default.jpg
#
#     date
# 0  13.09
# 1  13.09

# %% [markdown]
# ## Question 0

# %% [markdown]
# ### Netoyer les données

# %%
df_youtube['date'] = pd.to_datetime(df_youtube['date'], errors='coerce')
df_youtube = df_youtube.dropna(subset=['date'])


df_youtube.rename(columns={'video_id':'_id'}, inplace=True)

df_youtube = df_youtube.drop_duplicates(subset='_id', keep='last')

l_d =df_youtube.to_dict(orient='records')

import json
with open('./data/US_category_id.json', 'r') as f:
    categ = json.load(f)

for video in l_d:
    for cat in categ['items']:
        if video['category_id'] == int(cat['id']):
            video['category_name'] = cat['snippet']['title']

# %% [markdown]
# ### Importer les données

# %%
collection.insert_many(l_d)

# %% [markdown]
# ## Question 1

# %%
cur = collection.find({"channel_title":"Apple"})
list(cur)
# Out:
# [{'_id': 'K4wEI5zhHB0',
#   'title': 'iPhone X — Introducing iPhone X — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|iPhone 10|iPhone Ten|iPhone|Portrait Lighting|A11 Bionic|augmented reality|emoji|animoji|Face ID|Apple Pay|camera|smartphone',
#   'views': 19707391,
#   'likes': 381919,
#   'dislikes': 69465,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/K4wEI5zhHB0/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Science & Technology'},
#  {'_id': 'A9k88sMyiJM',
#   'title': 'Apple Watch Series 3 + Apple Music — Roll — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|airpods|apple watch|apple watch series 3|apple watch cellular|apple watch 4g|apple music|40 million songs on your wrist|apple skateboard ad|apple train station ad|apple roll ad|apple watch skateboard ad|apple watch train station ad|apple watch roll ad|airpods skateboard ad|airpods train station ad|airpods roll ad|apple music skateboard ad|apple music train station ad|apple music roll ad|misbehaving',
#   'views': 4112187,
#   'likes': 26609,
#   'dislikes': 8982,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/A9k88sMyiJM/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Science & Technology'},
#  {'_id': 'REZl-ANYKKY',
#   'title': 'iPhone 8 Plus — Portraits of Her  — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|new|iPhone|iPhone 8|iPhone 8 Plus|iOS 11|4.7-inch|5.5-inch|Portrait Lighting|Shot on iPhone|camera|iphonography|smartphone|This Strange Effect|The Shacks',
#   'views': 183325,
#   'likes': 1700,
#   'dislikes': 570,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/REZl-ANYKKY/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Science & Technology'}]

# %% [markdown]
# ## Question 2

# %%
cur = collection.aggregate([
    {"$group":{"_id":"$category_name"}},
    {"$group":{"_id":0,"nb":{"$sum":1}}}
])
list(cur)
# Out:
# [{'_id': 0, 'nb': 16}]

# %% [markdown]
# ## Question 3

# %%
result = collection.update_many({},{"$set":{"tags":{"$split":["$tags","|"]}}})
result
list(collection.find())
result = collection.delete_many({})
result
# Out:
# [{'_id': '5ywKal6-anc',
#   'title': 'Gigi Hadid Loses High Heel During Fashion Week, Walks It Off Like a Pro | TMZ',
#   'channel_title': 'TMZ',
#   'category_id': 24,
#   'tags': {'split': ['$tags', '|']},
#   'views': 703750,
#   'likes': 2921,
#   'dislikes': 2196,
#   'comment_total': 1042,
#   'thumbnail_link': 'https://i.ytimg.com/vi/5ywKal6-anc/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Entertainment'},
#  {'_id': 'GGm0FQ6i74U',
#   'title': 'What Hillary Clinton really thinks',
#   'channel_title': 'Vox',
#   'category_id': 25,
#   'tags': {'split': ['$tags', '|']},
#   'views': 244433,
#   'likes': 9143,
#   'dislikes': 6826,
#   'comment_total': 4838,
#   'thumbnail_link': 'https://i.ytimg.com/vi/GGm0FQ6i74U/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'News & Politics'},
#  {'_id': 'qJJHhVf3_ZM',
#   'title': "Gwyneth Paltrow Crashes James' Goop Magazine Rant",
#   'channel_title': 'The Late Late Show with James Corden',
#   'category_id': 24,
#   'tags': {'split': ['$tags', '|']},
#   'views': 220661,
#   'likes': 2070,
#   'dislikes': 449,
#   'comment_total': 352,
#   'thumbnail_link': 'https://i.ytimg.com/vi/qJJHhVf3_ZM/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Entertainment'},
#  {'_id': '9CILSvf1snQ',
#   'title': 'GOLD DIVA MACARONS- The Scran Line',
#   'channel_title': 'The Scran Line',
#   'category_id': 26,
#   'tags': {'split': ['$tags', '|']},
#   'views': 27794,
#   'likes': 1692,
#   'dislikes': 34,
#   'comment_total': 174,
#   'thumbnail_link': 'https://i.ytimg.com/vi/9CILSvf1snQ/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Howto & Style'},
#  {'_id': 'k9bYO7uSnrg',
#   'title': 'iPhone X hands on',
#   'channel_title': 'TechCrunch',
#   'category_id': 28,
#   'tags': {'split': ['$tags', '|']},
#   'views': 14577,
#   'likes': 160,
#   'dislikes': 19,
#   'comment_total': 51,
#   'thumbnail_link': 'https://i.ytimg.com/vi/k9bYO7uSnrg/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Science & Technology'},
#  {'_id': 'BRzPaDMeRks',
#   'title': 'These Are The Best Features Coming To iPhones.',
#   'channel_title': 'UrAvgConsumer',
#   'category_id': 28,
#   'tags': {'split': ['$tags', '|']},
#   'views': 352284,
#   'likes': 13099,
#   'dislikes': 508,
#   'comment_total': 1297,
#   'thumbnail_link': 'https://i.ytimg.com/vi/BRzPaDMeRks/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Science & Technology'},
#  {'_id': '-tCu0tKrzhc',
#   'title': 'Sloane Stephens jokes that $3.7 million check inspires her to keep playing | ESPN',
#   'channel_title': 'ESPN',
#   'category_id': 17,
#   'tags': {'split': ['$tags', '|']},
#   'views': 113400,
#   'likes': 1049,
#   'dislikes': 20,
#   'comment_total': 297,
#   'thumbnail_link': 'https://i.ytimg.com/vi/-tCu0tKrzhc/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Sports'},
#  {'_id': 'WCKJPn1UcXc',
#   'title': 'One America Appeal: Our Friends In Texas',
#   'channel_title': 'One America Appeal',
#   'category_id': 22,
#   'tags': {'split': ['$tags', '|']},
#   'views': 952945,
#   'likes': 17703,
#   'dislikes': 3207,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/WCKJPn1UcXc/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'People & Blogs'},
#  {'_id': 'TDskW3JvTAY',
#   'title': 'ANVIL Vs. WATERMELON PYRAMID! (CRAZY 45m DROP TESTS)',
#   'channel_title': 'How Ridiculous',
#   'category_id': 17,
#   'tags': {'split': ['$tags', '|']},
#   'views': 277903,
#   'likes': 13343,
#   'dislikes': 212,
#   'comment_total': 6348,
#   'thumbnail_link': 'https://i.ytimg.com/vi/TDskW3JvTAY/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Sports'},
#  {'_id': 'U2CqZNd6rgM',
#   'title': 'Welcome to JURASSIC FALLS!',
#   'channel_title': 'Brave Wilderness',
#   'category_id': 15,
#   'tags': {'split': ['$tags', '|']},
#   'views': 2384595,
#   'likes': 50009,
#   'dislikes': 1918,
#   'comment_total': 6584,
#   'thumbnail_link': 'https://i.ytimg.com/vi/U2CqZNd6rgM/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Pets & Animals'},
#  {'_id': 'FTIStPerVNw',
#   'title': 'Bernie Sanders Tries To Say Something Nice About Trump',
#   'channel_title': 'The Late Show with Stephen Colbert',
#   'category_id': 24,
#   'tags': {'split': ['$tags', '|']},
#   'views': 1493731,
#   'likes': 23472,
#   'dislikes': 3490,
#   'comment_total': 5872,
#   'thumbnail_link': 'https://i.ytimg.com/vi/FTIStPerVNw/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Entertainment'},
#  {'_id': 'AX8-YzMKZhQ',
#   'title': 'Sam Smith - Too Good At Goodbyes (Official Audio)',
#   'channel_title': 'SamSmithWorldVEVO',
#   'category_id': 10,
#   'tags': {'split': ['$tags', '|']},
#   'views': 13728070,
#   'likes': 468636,
#   'dislikes': 6597,
#   'comment_total': 20989,
#   'thumbnail_link': 'https://i.ytimg.com/vi/AX8-YzMKZhQ/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Music'},
#  {'_id': 'c3pFWJCQy5E',
#   'title': 'Update: Problem with Chemo Pills',
#   'channel_title': 'Courtelizz1',
#   'category_id': 26,
#   'tags': {'split': ['$tags', '|']},
#   'views': 108839,
#   'likes': 3677,
#   'dislikes': 107,
#   'comment_total': 732,
#   'thumbnail_link': 'https://i.ytimg.com/vi/c3pFWJCQy5E/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Howto & Style'},
#  {'_id': 'eJB1gcydsbU',
#   'title': 'If kids shows were honest about life',
#   'channel_title': 'AnthonyPadilla',
#   'category_id': 23,
#   'tags': {'split': ['$tags', '|']},
#   'views': 614717,
#   'likes': 49443,
#   'dislikes': 1986,
#   'comment_total': 3970,
#   'thumbnail_link': 'https://i.ytimg.com/vi/eJB1gcydsbU/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Comedy'},
#  {'_id': 'AR4UgRJOUQY',
#   'title': 'What Does Your Search History Say About You?',
#   'channel_title': 'AsapSCIENCE',
#   'category_id': 28,
#   'tags': {'split': ['$tags', '|']},
#   'views': 1244953,
#   'likes': 29748,
#   'dislikes': 2639,
#   'comment_total': 4112,
#   'thumbnail_link': 'https://i.ytimg.com/vi/AR4UgRJOUQY/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Science & Technology'},
#  {'_id': 'DGlYMJRwevI',
#   'title': 'Nerf meets Call of Duty: Gun Game 8.0 | First Person in 4K!',
#   'channel_title': 'Aaron Esser',
#   'category_id': 24,
#   'tags': {'split': ['$tags', '|']},
#   'views': 1862718,
#   'likes': 21516,
#   'dislikes': 1960,
#   'comment_total': 2108,
#   'thumbnail_link': 'https://i.ytimg.com/vi/DGlYMJRwevI/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Entertainment'},
#  {'_id': 'PGfSaVDymjk',
#   'title': 'G-Eazy - No Limit (Audio) ft. A$AP Rocky, Cardi B',
#   'channel_title': 'GEazyMusicVEVO',
#   'category_id': 10,
#   'tags': {'split': ['$tags', '|']},
#   'views': 2114219,
#   'likes': 77679,
#   'dislikes': 1874,
#   'comment_total': 4529,
#   'thumbnail_link': 'https://i.ytimg.com/vi/PGfSaVDymjk/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Music'},
#  {'_id': 'a2B9pA8aGUc',
#   'title': 'Rutgers Falls To Eastern Michigan',
#   'channel_title': 'Big Ten Network',
#   'category_id': 17,
#   'tags': {'split': ['$tags', '|']},
#   'views': 11533,
#   'likes': 51,
#   'dislikes': 7,
#   'comment_total': 29,
#   'thumbnail_link': 'https://i.ytimg.com/vi/a2B9pA8aGUc/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Sports'},
#  {'_id': '4Ltc4HO3NIE',
#   'title': 'Florida Weather Cameras - Hurricane Irma (19 cameras across Florida)',
#   'channel_title': 'stere0123',
#   'category_id': 19,
#   'tags': {'split': ['$tags', '|']},
#   'views': 109422,
#   'likes': 200,
#   'dislikes': 14,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/4Ltc4HO3NIE/default_live.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Travel & Events'},
#  {'_id': 'A-fofQ9VpPQ',
#   'title': 'Alias Grace | Official Trailer [HD] | Netflix',
#   'channel_title': 'Netflix',
#   'category_id': 24,
#   'tags': {'split': ['$tags', '|']},
#   'views': 349856,
#   'likes': 4403,
#   'dislikes': 140,
#   'comment_total': 335,
#   'thumbnail_link': 'https://i.ytimg.com/vi/A-fofQ9VpPQ/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Entertainment'},
#  {'_id': 'pCSgWJzEvrM',
#   'title': "The only dating advice you'll ever need",
#   'channel_title': 'Anna Akana',
#   'category_id': 23,
#   'tags': {'split': ['$tags', '|']},
#   'views': 447037,
#   'likes': 25068,
#   'dislikes': 710,
#   'comment_total': 1299,
#   'thumbnail_link': 'https://i.ytimg.com/vi/pCSgWJzEvrM/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Comedy'},
#  {'_id': 'bnON1y-fKag',
#   'title': 'Home Again - Movie Review',
#   'channel_title': 'Chris Stuckmann',
#   'category_id': 24,
#   'tags': {'split': ['$tags', '|']},
#   'views': 226012,
#   'likes': 9353,
#   'dislikes': 156,
#   'comment_total': 1282,
#   'thumbnail_link': 'https://i.ytimg.com/vi/bnON1y-fKag/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Entertainment'},
#  {'_id': 'VCVjbrt30tY',
#   'title': 'Fifth Harmony - Deliver',
#   'channel_title': 'FifthHarmonyVEVO',
#   'category_id': 10,
#   'tags': {'split': ['$tags', '|']},
#   'views': 3998451,
#   'likes': 291383,
#   'dislikes': 11624,
#   'comment_total': 24246,
#   'thumbnail_link': 'https://i.ytimg.com/vi/VCVjbrt30tY/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Music'},
#  {'_id': '2caEL5ATPX4',
#   'title': 'Janet Jackson performs Dammn Baby & I Get Lonely live State Of The World Tour',
#   'channel_title': 'Concert Daily',
#   'category_id': 10,
#   'tags': {'split': ['$tags', '|']},
#   'views': 82199,
#   'likes': 1194,
#   'dislikes': 51,
#   'comment_total': 194,
#   'thumbnail_link': 'https://i.ytimg.com/vi/2caEL5ATPX4/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Music'},
#  {'_id': 'Ie50Nw9NkOk',
#   'title': 'Jordan Peele and Spike Lee Team Up for Movie About Black Cop Who Infiltrated the KKK',
#   'channel_title': 'Complex News',
#   'category_id': 24,
#   'tags': {'split': ['$tags', '|']},
#   'views': 41962,
#   'likes': 1445,
#   'dislikes': 50,
#   'comment_total': 268,
#   'thumbnail_link': 'https://i.ytimg.com/vi/Ie50Nw9NkOk/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Entertainment'},
#  {'_id': 'tt2k8PGm-TI',
#   'title': 'ZAYN - Dusk Till Dawn ft. Sia',
#   'channel_title': 'ZaynVEVO',
#   'category_id': 10,
#   'tags': {'split': ['$tags', '|']},
#   'views': 36323498,
#   'likes': 1431683,
#   'dislikes': 28049,
#   'comment_total': 100661,
#   'thumbnail_link': 'https://i.ytimg.com/vi/tt2k8PGm-TI/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Music'},
#  {'_id': 'mGqR9sgMIyA',
#   'title': 'Orlando braces for Hurricane Irma',
#   'channel_title': 'Fox News',
#   'category_id': 25,
#   'tags': {'split': ['$tags', '|']},
#   'views': 25652,
#   'likes': 73,
#   'dislikes': 11,
#   'comment_total': 62,
#   'thumbnail_link': 'https://i.ytimg.com/vi/mGqR9sgMIyA/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'News & Politics'},
#  {'_id': 'D1KpuWg2hc0',
#   'title': "IT's Nicholas Hamilton & Chosen Jacobs Play RAW's Whisper Challenge",
#   'channel_title': 'RAW',
#   'category_id': 22,
#   'tags': {'split': ['$tags', '|']},
#   'views': 7563,
#   'likes': 344,
#   'dislikes': 1,
#   'comment_total': 21,
#   'thumbnail_link': 'https://i.ytimg.com/vi/D1KpuWg2hc0/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'People & Blogs'},
#  {'_id': 'qh7QJ_jLam0',
#   'title': 'Green Day - Too Dumb to Die (Official Lyric Video)',
#   'channel_title': 'Green Day',
#   'category_id': 10,
#   'tags': {'split': ['$tags', '|']},
#   'views': 845694,
#   'likes': 64515,
#   'dislikes': 625,
#   'comment_total': 4325,
#   'thumbnail_link': 'https://i.ytimg.com/vi/qh7QJ_jLam0/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Music'},
#  {'_id': 'XovZ04gmQgE',
#   'title': 'Hailee Steinfeld & Alesso (ft. Florida Georgia Line & watt) - Let Me Go (Official Audio)',
#   'channel_title': 'Hailee Steinfeld',
#   'category_id': 22,
#   'tags': {'split': ['$tags', '|']},
#   'views': 316616,
#   'likes': 10084,
#   'dislikes': 104,
#   'comment_total': 331,
#   'thumbnail_link': 'https://i.ytimg.com/vi/XovZ04gmQgE/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'People & Blogs'},
#  {'_id': 'Zy6vBxqlapw',
#   'title': 'Kelly Clarkson - Love So Soft [Official Video]',
#   'channel_title': 'Kelly Clarkson',
#   'category_id': 10,
#   'tags': {'split': ['$tags', '|']},
#   'views': 3027926,
#   'likes': 76505,
#   'dislikes': 2880,
#   'comment_total': 6414,
#   'thumbnail_link': 'https://i.ytimg.com/vi/Zy6vBxqlapw/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Music'},
#  {'_id': 'VEoITVHfyGg',
#   'title': 'Harry Potter Theory: The History Of Hagrid’s Wand',
#   'channel_title': 'SuperCarlinBrothers',
#   'category_id': 22,
#   'tags': {'split': ['$tags', '|']},
#   'views': 463409,
#   'likes': 19286,
#   'dislikes': 393,
#   'comment_total': 2304,
#   'thumbnail_link': 'https://i.ytimg.com/vi/VEoITVHfyGg/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'People & Blogs'},
#  {'_id': 'XwW6ZWaQ4bs',
#   'title': 'Hurricanes Irma, Jose, and Katia, all at once on 9/6/17',
#   'channel_title': 'WKRG',
#   'category_id': 25,
#   'tags': {'split': ['$tags', '|']},
#   'views': 4761358,
#   'likes': 50802,
#   'dislikes': 1128,
#   'comment_total': 8606,
#   'thumbnail_link': 'https://i.ytimg.com/vi/XwW6ZWaQ4bs/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'News & Politics'},
#  {'_id': 'Lv5DFKceFac',
#   'title': 'Thomas Rhett - Sweetheart (Static Video)',
#   'channel_title': 'ThomasRhettVEVO',
#   'category_id': 10,
#   'tags': {'split': ['$tags', '|']},
#   'views': 376381,
#   'likes': 8909,
#   'dislikes': 170,
#   'comment_total': 334,
#   'thumbnail_link': 'https://i.ytimg.com/vi/Lv5DFKceFac/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Music'},
#  {'_id': '4v38ugGj3u0',
#   'title': 'Suburbicon - Trailer 2',
#   'channel_title': 'Deadline Hollywood',
#   'category_id': 24,
#   'tags': {'split': ['$tags', '|']},
#   'views': 30851,
#   'likes': 261,
#   'dislikes': 65,
#   'comment_total': 49,
#   'thumbnail_link': 'https://i.ytimg.com/vi/4v38ugGj3u0/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Entertainment'},
#  {'_id': 'dA5qYrboTUE',
#   'title': 'Live footage as Hurricane Irma destroys Maho Beach Cam in St Maarten   9/6/2017',
#   'channel_title': 'PTZtv',
#   'category_id': 25,
#   'tags': {'split': ['$tags', '|']},
#   'views': 13752002,
#   'likes': 46101,
#   'dislikes': 4898,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/dA5qYrboTUE/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'News & Politics'},
#  {'_id': 'H_A0Z4S30Ds',
#   'title': 'Avenged Sevenfold - As Tears Go By',
#   'channel_title': 'AvengedSevenfoldVEVO',
#   'category_id': 10,
#   'tags': {'split': ['$tags', '|']},
#   'views': 433708,
#   'likes': 24188,
#   'dislikes': 712,
#   'comment_total': 2383,
#   'thumbnail_link': 'https://i.ytimg.com/vi/H_A0Z4S30Ds/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Music'},
#  {'_id': 'ton42cZ6ZYU',
#   'title': 'Acting Out My REAL Childhood Stories (PART 1)',
#   'channel_title': 'IISuperwomanII',
#   'category_id': 23,
#   'tags': {'split': ['$tags', '|']},
#   'views': 2465146,
#   'likes': 179085,
#   'dislikes': 1567,
#   'comment_total': 11973,
#   'thumbnail_link': 'https://i.ytimg.com/vi/ton42cZ6ZYU/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Comedy'},
#  {'_id': 'ZXvbz8cqafM',
#   'title': 'Taylor Swift NOW Presents: See What Taylor’s Up To NOW | AT&T',
#   'channel_title': 'AT&T',
#   'category_id': 10,
#   'tags': {'split': ['$tags', '|']},
#   'views': 836472,
#   'likes': 19314,
#   'dislikes': 1206,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/ZXvbz8cqafM/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Music'},
#  {'_id': 'lBspB4K-F-c',
#   'title': 'American Horror Story: CULT BEE HIVE',
#   'channel_title': 'Madeyewlook',
#   'category_id': 26,
#   'tags': {'split': ['$tags', '|']},
#   'views': 599780,
#   'likes': 29851,
#   'dislikes': 299,
#   'comment_total': 453,
#   'thumbnail_link': 'https://i.ytimg.com/vi/lBspB4K-F-c/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Howto & Style'},
#  {'_id': 'mTnRc4pVu4w',
#   'title': 'Lecrae - Hammer Time (Dance Visual) ft. 1K Phew',
#   'channel_title': 'LecraeVEVO',
#   'category_id': 10,
#   'tags': {'split': ['$tags', '|']},
#   'views': 106186,
#   'likes': 4695,
#   'dislikes': 193,
#   'comment_total': 396,
#   'thumbnail_link': 'https://i.ytimg.com/vi/mTnRc4pVu4w/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Music'},
#  {'_id': 'xo2B67vz4HA',
#   'title': 'Small Hands Samsung Galaxy Note 8 Review',
#   'channel_title': 'Linus Tech Tips',
#   'category_id': 28,
#   'tags': {'split': ['$tags', '|']},
#   'views': 626600,
#   'likes': 20553,
#   'dislikes': 1033,
#   'comment_total': 2138,
#   'thumbnail_link': 'https://i.ytimg.com/vi/xo2B67vz4HA/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Science & Technology'},
#  {'_id': 'rAh_16nooZA',
#   'title': 'ONLINE SHOPPING HAUL 2017! (with me, a shopaholic)',
#   'channel_title': 'Amber Scholl',
#   'category_id': 26,
#   'tags': {'split': ['$tags', '|']},
#   'views': 384682,
#   'likes': 21302,
#   'dislikes': 353,
#   'comment_total': 1559,
#   'thumbnail_link': 'https://i.ytimg.com/vi/rAh_16nooZA/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Howto & Style'},
#  {'_id': 'PPg1gN_ey2o',
#   'title': "Liza Koshy's Dream Office Makeover | OMG We're Coming Over | Mr. Kate",
#   'channel_title': 'Mr. Kate',
#   'category_id': 26,
#   'tags': {'split': ['$tags', '|']},
#   'views': 2451184,
#   'likes': 176110,
#   'dislikes': 1017,
#   'comment_total': 6257,
#   'thumbnail_link': 'https://i.ytimg.com/vi/PPg1gN_ey2o/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Howto & Style'},
#  {'_id': 'k0WRpQU9zK0',
#   'title': "R3HAB & Quintino  - I Just Can't (Official Video)",
#   'channel_title': 'R3HAB',
#   'category_id': 10,
#   'tags': {'split': ['$tags', '|']},
#   'views': 480279,
#   'likes': 26662,
#   'dislikes': 241,
#   'comment_total': 557,
#   'thumbnail_link': 'https://i.ytimg.com/vi/k0WRpQU9zK0/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Music'},
#  {'_id': '-1fzGnFwz9M',
#   'title': "9 Things You Need To Know About Kittens - Simon's Cat | 101",
#   'channel_title': "Simon's Cat",
#   'category_id': 15,
#   'tags': {'split': ['$tags', '|']},
#   'views': 189414,
#   'likes': 7070,
#   'dislikes': 112,
#   'comment_total': 288,
#   'thumbnail_link': 'https://i.ytimg.com/vi/-1fzGnFwz9M/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Pets & Animals'},
#  {'_id': 'ezgtjMfgxos',
#   'title': 'Watch Live Satellite Images Of Hurricane Irma: Evacuation Orders In Place In Florida | TIME',
#   'channel_title': 'TIME',
#   'category_id': 25,
#   'tags': {'split': ['$tags', '|']},
#   'views': 103666,
#   'likes': 196,
#   'dislikes': 67,
#   'comment_total': 80,
#   'thumbnail_link': 'https://i.ytimg.com/vi/ezgtjMfgxos/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'News & Politics'},
#  {'_id': 'fM8yID63CSA',
#   'title': 'GAGA: FIVE FOOT TWO Press Conference | Festival 2017',
#   'channel_title': 'TIFF',
#   'category_id': 1,
#   'tags': {'split': ['$tags', '|']},
#   'views': 74494,
#   'likes': 2218,
#   'dislikes': 37,
#   'comment_total': 159,
#   'thumbnail_link': 'https://i.ytimg.com/vi/fM8yID63CSA/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Film & Animation'},
#  {'_id': 'vu_9muoxT50',
#   'title': "Colin Cloud: Mind Reader Predicts Your Tweets - America's Got Talent 2017",
#   'channel_title': "America's Got Talent",
#   'category_id': 24,
#   'tags': {'split': ['$tags', '|']},
#   'views': 990274,
#   'likes': 22897,
#   'dislikes': 639,
#   'comment_total': 2430,
#   'thumbnail_link': 'https://i.ytimg.com/vi/vu_9muoxT50/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Entertainment'},
#  {'_id': 'xzPRACH6YwE',
#   'title': 'Fifth Harmony: He Like That',
#   'channel_title': 'The Late Late Show with James Corden',
#   'category_id': 24,
#   'tags': {'split': ['$tags', '|']},
#   'views': 378178,
#   'likes': 25046,
#   'dislikes': 1112,
#   'comment_total': 2510,
#   'thumbnail_link': 'https://i.ytimg.com/vi/xzPRACH6YwE/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Entertainment'},
#  {'_id': '62cWuFjzOgs',
#   'title': 'Apple Watch Series 3 hands-on live from Apple Event 2017',
#   'channel_title': 'Engadget',
#   'category_id': 28,
#   'tags': {'split': ['$tags', '|']},
#   'views': 65650,
#   'likes': 403,
#   'dislikes': 57,
#   'comment_total': 175,
#   'thumbnail_link': 'https://i.ytimg.com/vi/62cWuFjzOgs/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Science & Technology'},
#  {'_id': 'EVp4-qjWVJE',
#   'title': 'Chargers vs. Broncos | NFL Week 1 Game Highlights',
#   'channel_title': 'NFL',
#   'category_id': 17,
#   'tags': {'split': ['$tags', '|']},
#   'views': 829793,
#   'likes': 6501,
#   'dislikes': 386,
#   'comment_total': 2582,
#   'thumbnail_link': 'https://i.ytimg.com/vi/EVp4-qjWVJE/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Sports'},
#  {'_id': 'LDcm6twPEJA',
#   'title': 'The Problem With Our Phones',
#   'channel_title': 'The School of Life',
#   'category_id': 27,
#   'tags': {'split': ['$tags', '|']},
#   'views': 205103,
#   'likes': 10947,
#   'dislikes': 471,
#   'comment_total': 1206,
#   'thumbnail_link': 'https://i.ytimg.com/vi/LDcm6twPEJA/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Education'},
#  {'_id': 'L3f7_y9UPh4',
#   'title': 'Jimmy Kimmel Talks to Kristen Bell in Orlando After Hurricane Irma',
#   'channel_title': 'Jimmy Kimmel Live',
#   'category_id': 23,
#   'tags': {'split': ['$tags', '|']},
#   'views': 310292,
#   'likes': 4598,
#   'dislikes': 155,
#   'comment_total': 371,
#   'thumbnail_link': 'https://i.ytimg.com/vi/L3f7_y9UPh4/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Comedy'},
#  {'_id': '6vGg-jJl30A',
#   'title': 'THIS MADE MY DAD CRY! | Story of my Comeback Competition',
#   'channel_title': 'Nile Wilson',
#   'category_id': 17,
#   'tags': {'split': ['$tags', '|']},
#   'views': 214484,
#   'likes': 12908,
#   'dislikes': 125,
#   'comment_total': 937,
#   'thumbnail_link': 'https://i.ytimg.com/vi/6vGg-jJl30A/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Sports'},
#  {'_id': 'LTnl36-0-zU',
#   'title': "After Hours: 6 Movies Whose Timelines Don't Add Up",
#   'channel_title': 'Cracked',
#   'category_id': 23,
#   'tags': {'split': ['$tags', '|']},
#   'views': 410406,
#   'likes': 14671,
#   'dislikes': 344,
#   'comment_total': 1407,
#   'thumbnail_link': 'https://i.ytimg.com/vi/LTnl36-0-zU/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Comedy'},
#  {'_id': 'zAXn-v9RdXo',
#   'title': "Surveying Hurricane Irma's Damage in Southwest Florida",
#   'channel_title': 'The New York Times',
#   'category_id': 25,
#   'tags': {'split': ['$tags', '|']},
#   'views': 9396,
#   'likes': 76,
#   'dislikes': 2,
#   'comment_total': 13,
#   'thumbnail_link': 'https://i.ytimg.com/vi/zAXn-v9RdXo/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'News & Politics'},
#  {'_id': '1Sm8A-u1vIA',
#   'title': 'LIVE TRACKING OF HURRICANE IRMA',
#   'channel_title': 'ABC Action News',
#   'category_id': 24,
#   'tags': {'split': ['$tags', '|']},
#   'views': 7198312,
#   'likes': 26768,
#   'dislikes': 3932,
#   'comment_total': 147,
#   'thumbnail_link': 'https://i.ytimg.com/vi/1Sm8A-u1vIA/default_live.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Entertainment'},
#  {'_id': '0Yhaei1S5oQ',
#   'title': "Japan's Ominous Dancing Cats and the Disaster That Followed",
#   'channel_title': 'SciShow',
#   'category_id': 27,
#   'tags': {'split': ['$tags', '|']},
#   'views': 307749,
#   'likes': 11202,
#   'dislikes': 150,
#   'comment_total': 800,
#   'thumbnail_link': 'https://i.ytimg.com/vi/0Yhaei1S5oQ/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Education'},
#  {'_id': 'oePt4JgdyZo',
#   'title': 'Rick and Morty Character Studies: Why is Rick Such a Rick?',
#   'channel_title': 'ScreenPrism',
#   'category_id': 1,
#   'tags': {'split': ['$tags', '|']},
#   'views': 170608,
#   'likes': 3442,
#   'dislikes': 303,
#   'comment_total': 381,
#   'thumbnail_link': 'https://i.ytimg.com/vi/oePt4JgdyZo/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Film & Animation'},
#  {'_id': 'fCh5TVGaTSg',
#   'title': 'Tracking Hurricane Irma 9/11',
#   'channel_title': 'CBS Miami',
#   'category_id': 25,
#   'tags': {'split': ['$tags', '|']},
#   'views': 91906,
#   'likes': 270,
#   'dislikes': 62,
#   'comment_total': 219,
#   'thumbnail_link': 'https://i.ytimg.com/vi/fCh5TVGaTSg/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'News & Politics'},
#  {'_id': 'u6iVspBWzZU',
#   'title': 'what is derealisation / depersonalisation?',
#   'channel_title': 'doddlevloggle',
#   'category_id': 24,
#   'tags': {'split': ['$tags', '|']},
#   'views': 168561,
#   'likes': 20645,
#   'dislikes': 81,
#   'comment_total': 2100,
#   'thumbnail_link': 'https://i.ytimg.com/vi/u6iVspBWzZU/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Entertainment'},
#  {'_id': '-cYk6sbe11c',
#   'title': 'Hurricane Irma Makes Landfall in Florida Keys as Powerful Category 4 | TODAY',
#   'channel_title': 'TODAY',
#   'category_id': 25,
#   'tags': {'split': ['$tags', '|']},
#   'views': 329907,
#   'likes': 1158,
#   'dislikes': 190,
#   'comment_total': 434,
#   'thumbnail_link': 'https://i.ytimg.com/vi/-cYk6sbe11c/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'News & Politics'},
#  {'_id': 'U1bpztJkdzk',
#   'title': 'TESTING WEIRD PUPPY TOYS WITH PUPPY!!! *CUTE*',
#   'channel_title': 'LaurDIY',
#   'category_id': 26,
#   'tags': {'split': ['$tags', '|']},
#   'views': 1043993,
#   'likes': 58482,
#   'dislikes': 588,
#   'comment_total': 3389,
#   'thumbnail_link': 'https://i.ytimg.com/vi/U1bpztJkdzk/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Howto & Style'},
#  {'_id': 'Mq9dxmh6JiE',
#   'title': 'FENTY BEAUTY by RIHANNA FULL REVIEW',
#   'channel_title': 'James Charles',
#   'category_id': 24,
#   'tags': {'split': ['$tags', '|']},
#   'views': 1228127,
#   'likes': 47168,
#   'dislikes': 4719,
#   'comment_total': 6048,
#   'thumbnail_link': 'https://i.ytimg.com/vi/Mq9dxmh6JiE/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Entertainment'},
#  {'_id': '7Gw-lN270qs',
#   'title': '10 Hour Test On These 5 Cult Beauty Buys | Full Face First Impressions | Beauty With Mi',
#   'channel_title': 'Refinery29',
#   'category_id': 26,
#   'tags': {'split': ['$tags', '|']},
#   'views': 16296,
#   'likes': 361,
#   'dislikes': 32,
#   'comment_total': 85,
#   'thumbnail_link': 'https://i.ytimg.com/vi/7Gw-lN270qs/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Howto & Style'},
#  {'_id': 'lwOQbMcXtfU',
#   'title': 'Dried up Beach in the Bahamas',
#   'channel_title': 'ViralHog',
#   'category_id': 22,
#   'tags': {'split': ['$tags', '|']},
#   'views': 1297769,
#   'likes': 2727,
#   'dislikes': 514,
#   'comment_total': 934,
#   'thumbnail_link': 'https://i.ytimg.com/vi/lwOQbMcXtfU/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'People & Blogs'},
#  {'_id': '_NlKTMvnjIc',
#   'title': "Hurricane Irma Now a Category 3, Could 'Re-Engergize' to Category 4 | MSNBC",
#   'channel_title': 'MSNBC',
#   'category_id': 25,
#   'tags': {'split': ['$tags', '|']},
#   'views': 1774499,
#   'likes': 8057,
#   'dislikes': 2128,
#   'comment_total': 3396,
#   'thumbnail_link': 'https://i.ytimg.com/vi/_NlKTMvnjIc/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'News & Politics'},
#  {'_id': 'Pp19TkIU_fw',
#   'title': 'Life of Kylie Recap Season 1, Ep.7 | E!',
#   'channel_title': 'E! Entertainment',
#   'category_id': 24,
#   'tags': {'split': ['$tags', '|']},
#   'views': 200970,
#   'likes': 2034,
#   'dislikes': 271,
#   'comment_total': 199,
#   'thumbnail_link': 'https://i.ytimg.com/vi/Pp19TkIU_fw/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Entertainment'},
#  {'_id': 'C3cwtcomilA',
#   'title': 'Galaxy Note 8 // 8 Things To Do First!',
#   'channel_title': 'Kevin The Tech Ninja',
#   'category_id': 28,
#   'tags': {'split': ['$tags', '|']},
#   'views': 11811,
#   'likes': 401,
#   'dislikes': 17,
#   'comment_total': 50,
#   'thumbnail_link': 'https://i.ytimg.com/vi/C3cwtcomilA/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Science & Technology'},
#  {'_id': '3x-sUsazQ90',
#   'title': "#IRMAgerd Hurricane Candy and why it's hard to make candy when it rains.",
#   'channel_title': 'Lofty Pursuits',
#   'category_id': 26,
#   'tags': {'split': ['$tags', '|']},
#   'views': 415382,
#   'likes': 12329,
#   'dislikes': 469,
#   'comment_total': 1746,
#   'thumbnail_link': 'https://i.ytimg.com/vi/3x-sUsazQ90/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Howto & Style'},
#  {'_id': 'PJZOghDtOCM',
#   'title': 'Hurricane Irma News Bloopers',
#   'channel_title': 'Funny Local News',
#   'category_id': 25,
#   'tags': {'split': ['$tags', '|']},
#   'views': 10892,
#   'likes': 60,
#   'dislikes': 1,
#   'comment_total': 26,
#   'thumbnail_link': 'https://i.ytimg.com/vi/PJZOghDtOCM/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'News & Politics'},
#  {'_id': '_uLmn_Dba08',
#   'title': '10 Hilarious Thrift Store Items!',
#   'channel_title': 'Matthias',
#   'category_id': 28,
#   'tags': {'split': ['$tags', '|']},
#   'views': 2064406,
#   'likes': 41329,
#   'dislikes': 2694,
#   'comment_total': 15667,
#   'thumbnail_link': 'https://i.ytimg.com/vi/_uLmn_Dba08/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Science & Technology'},
#  {'_id': '7Lyo5dCig-U',
#   'title': 'BBC Anchor Gets LOST on Camera (News Blooper)',
#   'channel_title': 'NewsFunnies',
#   'category_id': 25,
#   'tags': {'split': ['$tags', '|']},
#   'views': 273256,
#   'likes': 2408,
#   'dislikes': 121,
#   'comment_total': 263,
#   'thumbnail_link': 'https://i.ytimg.com/vi/7Lyo5dCig-U/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'News & Politics'},
#  {'_id': 'vSDCb3bdFlw',
#   'title': 'Hurricane Irma roars into the Florida Keys and continues up the coast',
#   'channel_title': 'ABC News',
#   'category_id': 25,
#   'tags': {'split': ['$tags', '|']},
#   'views': 50537,
#   'likes': 251,
#   'dislikes': 27,
#   'comment_total': 150,
#   'thumbnail_link': 'https://i.ytimg.com/vi/vSDCb3bdFlw/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'News & Politics'},
#  {'_id': 'BdV0dkx2oik',
#   'title': 'The Honda Civic has a very small feature, that I never noticed. Until now.',
#   'channel_title': "Jared's Garage",
#   'category_id': 2,
#   'tags': {'split': ['$tags', '|']},
#   'views': 667703,
#   'likes': 3996,
#   'dislikes': 722,
#   'comment_total': 280,
#   'thumbnail_link': 'https://i.ytimg.com/vi/BdV0dkx2oik/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Autos & Vehicles'},
#  {'_id': 'PTXykKsrxpY',
#   'title': "'I WILL KNOCK OUT ANTHONY JOSHUA!' - KUBRAT PULEV / AND ROUGHS UP & OFFERS TO FIGHT KUGAN CASSIUS!",
#   'channel_title': 'iFL TV',
#   'category_id': 17,
#   'tags': {'split': ['$tags', '|']},
#   'views': 137388,
#   'likes': 974,
#   'dislikes': 76,
#   'comment_total': 691,
#   'thumbnail_link': 'https://i.ytimg.com/vi/PTXykKsrxpY/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Sports'},
#  {'_id': 'rTMibYCQMyk',
#   'title': 'Served Like A Girl - Trailer',
#   'channel_title': 'Freestyle Digital Media',
#   'category_id': 1,
#   'tags': {'split': ['$tags', '|']},
#   'views': 9354,
#   'likes': 53,
#   'dislikes': 2,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/rTMibYCQMyk/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Film & Animation'},
#  {'_id': 'amds5iNvFD4',
#   'title': 'I Gave Myself A Celebrity Hair Transformation 💇🏾✂️',
#   'channel_title': 'Michelle Khare',
#   'category_id': 24,
#   'tags': {'split': ['$tags', '|']},
#   'views': 326281,
#   'likes': 8616,
#   'dislikes': 472,
#   'comment_total': 680,
#   'thumbnail_link': 'https://i.ytimg.com/vi/amds5iNvFD4/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Entertainment'},
#  {'_id': 'PHXkhUJWTXM',
#   'title': 'Hurricane Irma Emergency Fake Interpreter',
#   'channel_title': 'Jane Smith',
#   'category_id': 22,
#   'tags': {'split': ['$tags', '|']},
#   'views': 168512,
#   'likes': 224,
#   'dislikes': 72,
#   'comment_total': 182,
#   'thumbnail_link': 'https://i.ytimg.com/vi/PHXkhUJWTXM/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'People & Blogs'},
#  {'_id': 'X7ld45pUueQ',
#   'title': 'CHECK DESCRIPTION! Southern most point live webcam',
#   'channel_title': 'Kevin Novobilsky',
#   'category_id': 23,
#   'tags': {'split': ['$tags', '|']},
#   'views': 2333602,
#   'likes': 4894,
#   'dislikes': 940,
#   'comment_total': 445,
#   'thumbnail_link': 'https://i.ytimg.com/vi/X7ld45pUueQ/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Comedy'},
#  {'_id': '3hq2c9vdfls',
#   'title': 'Cal Football 2017: HC Justin Wilcox September 11, 2017',
#   'channel_title': 'Cal Bears',
#   'category_id': 17,
#   'tags': {'split': ['$tags', '|']},
#   'views': 1097,
#   'likes': 9,
#   'dislikes': 0,
#   'comment_total': 7,
#   'thumbnail_link': 'https://i.ytimg.com/vi/3hq2c9vdfls/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Sports'},
#  {'_id': 'wGQtrwey-TI',
#   'title': 'SALTED EGG CRAB! Street Food Tour of Old Airport Road Hawker Center',
#   'channel_title': 'Strictly Dumpling',
#   'category_id': 19,
#   'tags': {'split': ['$tags', '|']},
#   'views': 645414,
#   'likes': 13560,
#   'dislikes': 495,
#   'comment_total': 1792,
#   'thumbnail_link': 'https://i.ytimg.com/vi/wGQtrwey-TI/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Travel & Events'},
#  {'_id': '_GC5AVsf528',
#   'title': 'Nothing But Thieves - Sorry (Stripped Back)',
#   'channel_title': 'NBTVEVO',
#   'category_id': 10,
#   'tags': {'split': ['$tags', '|']},
#   'views': 103175,
#   'likes': 6708,
#   'dislikes': 68,
#   'comment_total': 345,
#   'thumbnail_link': 'https://i.ytimg.com/vi/_GC5AVsf528/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Music'},
#  {'_id': '7nh2Ra-5kY8',
#   'title': '2017 US Open: Sloane Stephens Takes The Title',
#   'channel_title': 'US Open Tennis Championships',
#   'category_id': 17,
#   'tags': {'split': ['$tags', '|']},
#   'views': 122620,
#   'likes': 756,
#   'dislikes': 49,
#   'comment_total': 445,
#   'thumbnail_link': 'https://i.ytimg.com/vi/7nh2Ra-5kY8/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Sports'},
#  {'_id': 'J_e77K4n6Ts',
#   'title': 'Garlic Knot Chicken Alfredo Ring',
#   'channel_title': 'Tasty',
#   'category_id': 26,
#   'tags': {'split': ['$tags', '|']},
#   'views': 358204,
#   'likes': 13019,
#   'dislikes': 196,
#   'comment_total': 521,
#   'thumbnail_link': 'https://i.ytimg.com/vi/J_e77K4n6Ts/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Howto & Style'},
#  {'_id': 'AHrCI9eSJGQ',
#   'title': '30 Days Timelapse at Sea | 4K | Through Thunderstorms, Torrential Rain & Busy Traffic',
#   'channel_title': 'JeffHK',
#   'category_id': 19,
#   'tags': {'split': ['$tags', '|']},
#   'views': 943682,
#   'likes': 59232,
#   'dislikes': 236,
#   'comment_total': 5468,
#   'thumbnail_link': 'https://i.ytimg.com/vi/AHrCI9eSJGQ/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Travel & Events'},
#  {'_id': 'jehAZhrI7oA',
#   'title': 'IT - SPOILER Talk',
#   'channel_title': 'Jeremy Jahns',
#   'category_id': 24,
#   'tags': {'split': ['$tags', '|']},
#   'views': 808962,
#   'likes': 17617,
#   'dislikes': 1060,
#   'comment_total': 5684,
#   'thumbnail_link': 'https://i.ytimg.com/vi/jehAZhrI7oA/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Entertainment'},
#  {'_id': 'qPDZZj6By3Y',
#   'title': 'Killer Whales Attack Minke - Frozen Planet - BBC Earth',
#   'channel_title': 'BBC Earth',
#   'category_id': 15,
#   'tags': {'split': ['$tags', '|']},
#   'views': 180554,
#   'likes': 3458,
#   'dislikes': 113,
#   'comment_total': 459,
#   'thumbnail_link': 'https://i.ytimg.com/vi/qPDZZj6By3Y/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Pets & Animals'},
#  {'_id': '0tOUQt5fem0',
#   'title': "First Tuned Run of Terry Mayhugh's Quarter Scale V12 Merlin",
#   'channel_title': 'mayhugh1',
#   'category_id': 2,
#   'tags': {'split': ['$tags', '|']},
#   'views': 8075,
#   'likes': 55,
#   'dislikes': 0,
#   'comment_total': 6,
#   'thumbnail_link': 'https://i.ytimg.com/vi/0tOUQt5fem0/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Autos & Vehicles'},
#  {'_id': 'zJufeAMRHy8',
#   'title': 'Rainbow Connection - The Muppets at The Hollywood Bowl - September 8, 2017 HD',
#   'channel_title': 'Synthetik Films',
#   'category_id': 10,
#   'tags': {'split': ['$tags', '|']},
#   'views': 96468,
#   'likes': 914,
#   'dislikes': 23,
#   'comment_total': 159,
#   'thumbnail_link': 'https://i.ytimg.com/vi/zJufeAMRHy8/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Music'},
#  {'_id': 'UpONjs5kLPc',
#   'title': 'Los jugadores de Sacachispas entraron vestidos de guerreros vs Sarmiento (Copa Argentina)',
#   'channel_title': 'Futbol La Pasion',
#   'category_id': 17,
#   'tags': {'split': ['$tags', '|']},
#   'views': 54261,
#   'likes': 203,
#   'dislikes': 4,
#   'comment_total': 30,
#   'thumbnail_link': 'https://i.ytimg.com/vi/UpONjs5kLPc/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Sports'},
#  {'_id': 'H9KaqCBEvvg',
#   'title': 'Rami Malek como Freddie Mercury en Live Aid',
#   'channel_title': 'A Queen Of Magic',
#   'category_id': 10,
#   'tags': {'split': ['$tags', '|']},
#   'views': 80647,
#   'likes': 475,
#   'dislikes': 23,
#   'comment_total': 106,
#   'thumbnail_link': 'https://i.ytimg.com/vi/H9KaqCBEvvg/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Music'},
#  {'_id': 'f5F2whaRzqw',
#   'title': 'Teardown and Experiments with a Doppler Microwave Transceiver',
#   'channel_title': 'Kerry Wong',
#   'category_id': 27,
#   'tags': {'split': ['$tags', '|']},
#   'views': 2953,
#   'likes': 105,
#   'dislikes': 0,
#   'comment_total': 21,
#   'thumbnail_link': 'https://i.ytimg.com/vi/f5F2whaRzqw/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Education'},
#  {'_id': 'MmAL1EOkLUo',
#   'title': 'SVU 9.11 Opener Dedication.wmv',
#   'channel_title': 'DarthLucifer08',
#   'category_id': 24,
#   'tags': {'split': ['$tags', '|']},
#   'views': 19468,
#   'likes': 87,
#   'dislikes': 2,
#   'comment_total': 14,
#   'thumbnail_link': 'https://i.ytimg.com/vi/MmAL1EOkLUo/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Entertainment'},
#  {'_id': '4LwpGaDKmZ8',
#   'title': 'FENTY BEAUTY by RIHANNA... HIT OR MISS?! | Jeffree Star',
#   'channel_title': 'jeffreestar',
#   'category_id': 26,
#   'tags': {'split': ['$tags', '|']},
#   'views': 5292941,
#   'likes': 187251,
#   'dislikes': 17328,
#   'comment_total': 19816,
#   'thumbnail_link': 'https://i.ytimg.com/vi/4LwpGaDKmZ8/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Howto & Style'},
#  {'_id': '5kZi3J2S52E',
#   'title': 'The Final Steps of Making Pyrimethamine (Daraprim)',
#   'channel_title': 'NurdRage',
#   'category_id': 27,
#   'tags': {'split': ['$tags', '|']},
#   'views': 231371,
#   'likes': 7945,
#   'dislikes': 47,
#   'comment_total': 786,
#   'thumbnail_link': 'https://i.ytimg.com/vi/5kZi3J2S52E/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Education'},
#  {'_id': 'Alp_a88C8dY',
#   'title': "Stephen King's IT - What's the Difference?",
#   'channel_title': 'CineFix',
#   'category_id': 24,
#   'tags': {'split': ['$tags', '|']},
#   'views': 1361619,
#   'likes': 20383,
#   'dislikes': 1020,
#   'comment_total': 3113,
#   'thumbnail_link': 'https://i.ytimg.com/vi/Alp_a88C8dY/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Entertainment'},
#  {'_id': 'WAwRqecvMSY',
#   'title': "ROASTING YOUTUBERS' NAILS (nail diss)",
#   'channel_title': 'Simply Nailogical',
#   'category_id': 24,
#   'tags': {'split': ['$tags', '|']},
#   'views': 1849541,
#   'likes': 135169,
#   'dislikes': 5430,
#   'comment_total': 23408,
#   'thumbnail_link': 'https://i.ytimg.com/vi/WAwRqecvMSY/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Entertainment'},
#  {'_id': 'pAsN4lSa7O0',
#   'title': "Blake Shelton - I'll Name The Dogs (Official Music Video)",
#   'channel_title': 'Blake Shelton',
#   'category_id': 10,
#   'tags': {'split': ['$tags', '|']},
#   'views': 1984548,
#   'likes': 25976,
#   'dislikes': 2917,
#   'comment_total': 2345,
#   'thumbnail_link': 'https://i.ytimg.com/vi/pAsN4lSa7O0/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Music'},
#  {'_id': 'uAipi4V5g34',
#   'title': "Dancing in 80's Movies Supercut - Vol. 2",
#   'channel_title': 'Robert Jones',
#   'category_id': 24,
#   'tags': {'split': ['$tags', '|']},
#   'views': 15093,
#   'likes': 210,
#   'dislikes': 3,
#   'comment_total': 26,
#   'thumbnail_link': 'https://i.ytimg.com/vi/uAipi4V5g34/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Entertainment'},
#  {'_id': '9e6WeQeBjOI',
#   'title': 'Dad Builds Palace For Dogs',
#   'channel_title': 'Caters Clips',
#   'category_id': 25,
#   'tags': {'split': ['$tags', '|']},
#   'views': 5266,
#   'likes': 29,
#   'dislikes': 0,
#   'comment_total': 13,
#   'thumbnail_link': 'https://i.ytimg.com/vi/9e6WeQeBjOI/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'News & Politics'},
#  {'_id': 'CayHgjP1YNQ',
#   'title': 'Game of Thrones sings Look What You Made Me Do',
#   'channel_title': 'Matthijs Vlot',
#   'category_id': 1,
#   'tags': {'split': ['$tags', '|']},
#   'views': 456328,
#   'likes': 4309,
#   'dislikes': 69,
#   'comment_total': 264,
#   'thumbnail_link': 'https://i.ytimg.com/vi/CayHgjP1YNQ/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Film & Animation'},
#  {'_id': 'xtDJ6uEyvnw',
#   'title': 'Hurricane Irma Warning With Sign Language',
#   'channel_title': 'Cole Truax',
#   'category_id': 22,
#   'tags': {'split': ['$tags', '|']},
#   'views': 58026,
#   'likes': 274,
#   'dislikes': 5,
#   'comment_total': 105,
#   'thumbnail_link': 'https://i.ytimg.com/vi/xtDJ6uEyvnw/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'People & Blogs'},
#  {'_id': '8QgMh02JvS8',
#   'title': 'The $80 Smartphone Challenge',
#   'channel_title': 'Austin Evans',
#   'category_id': 28,
#   'tags': {'split': ['$tags', '|']},
#   'views': 396083,
#   'likes': 12221,
#   'dislikes': 463,
#   'comment_total': 1772,
#   'thumbnail_link': 'https://i.ytimg.com/vi/8QgMh02JvS8/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Science & Technology'},
#  {'_id': 'frv64BFwGFY',
#   'title': 'Kmart - I Can',
#   'channel_title': 'Kmart',
#   'category_id': 24,
#   'tags': {'split': ['$tags', '|']},
#   'views': 122194,
#   'likes': 22,
#   'dislikes': 12,
#   'comment_total': 5,
#   'thumbnail_link': 'https://i.ytimg.com/vi/frv64BFwGFY/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Entertainment'},
#  {'_id': 'fQxLlq7lxVM',
#   'title': 'FENTY BEAUTY | FULL FACE BEAT,  IMPRESSIONS + REVIEW',
#   'channel_title': 'Shameless Maya',
#   'category_id': 26,
#   'tags': {'split': ['$tags', '|']},
#   'views': 414089,
#   'likes': 20839,
#   'dislikes': 521,
#   'comment_total': 6595,
#   'thumbnail_link': 'https://i.ytimg.com/vi/fQxLlq7lxVM/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Howto & Style'},
#  {'_id': 'T2W7UocH0Hs',
#   'title': 'How to Save Your Seat in Japan',
#   'channel_title': "Life Where I'm From",
#   'category_id': 22,
#   'tags': {'split': ['$tags', '|']},
#   'views': 110816,
#   'likes': 3644,
#   'dislikes': 110,
#   'comment_total': 719,
#   'thumbnail_link': 'https://i.ytimg.com/vi/T2W7UocH0Hs/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'People & Blogs'},
#  {'_id': 'zPGRU49esCU',
#   'title': 'How to Cook With No Power During a Hurricane #Irma',
#   'channel_title': 'Brothers Green Eats',
#   'category_id': 26,
#   'tags': {'split': ['$tags', '|']},
#   'views': 79080,
#   'likes': 2248,
#   'dislikes': 225,
#   'comment_total': 395,
#   'thumbnail_link': 'https://i.ytimg.com/vi/zPGRU49esCU/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Howto & Style'},
#  {'_id': 'ykvX-E1nuag',
#   'title': 'How to Win Australia',
#   'channel_title': 'vlogbrothers',
#   'category_id': 22,
#   'tags': {'split': ['$tags', '|']},
#   'views': 177155,
#   'likes': 9287,
#   'dislikes': 166,
#   'comment_total': 881,
#   'thumbnail_link': 'https://i.ytimg.com/vi/ykvX-E1nuag/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'People & Blogs'},
#  {'_id': '8fH_PAi6Yf4',
#   'title': 'RIHANNA FENTY BEAUTY My First Impressions Full Face + Review For Dark Skin | MsDebDeb',
#   'channel_title': 'Ms Deb Deb',
#   'category_id': 26,
#   'tags': {'split': ['$tags', '|']},
#   'views': 1139838,
#   'likes': 39393,
#   'dislikes': 1607,
#   'comment_total': 1519,
#   'thumbnail_link': 'https://i.ytimg.com/vi/8fH_PAi6Yf4/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Howto & Style'},
#  {'_id': 'a6sywFdvURE',
#   'title': "Steve Bannon: Trump's Access Hollywood tape was a litmus test",
#   'channel_title': 'CBS This Morning',
#   'category_id': 25,
#   'tags': {'split': ['$tags', '|']},
#   'views': 174184,
#   'likes': 462,
#   'dislikes': 86,
#   'comment_total': 303,
#   'thumbnail_link': 'https://i.ytimg.com/vi/a6sywFdvURE/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'News & Politics'},
#  {'_id': 'pwHvK07tUuw',
#   'title': '24 Genres. Two Artists. One song. All voices. - Shape of You Ed Sheeran',
#   'channel_title': 'Peter Hollens',
#   'category_id': 10,
#   'tags': {'split': ['$tags', '|']},
#   'views': 723981,
#   'likes': 50162,
#   'dislikes': 1000,
#   'comment_total': 4923,
#   'thumbnail_link': 'https://i.ytimg.com/vi/pwHvK07tUuw/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Music'},
#  {'_id': 'bF5sIEuv83k',
#   'title': 'Kane Brown - Found You (Audio)',
#   'channel_title': 'KaneBrownVEVO',
#   'category_id': 10,
#   'tags': {'split': ['$tags', '|']},
#   'views': 920080,
#   'likes': 21350,
#   'dislikes': 907,
#   'comment_total': 909,
#   'thumbnail_link': 'https://i.ytimg.com/vi/bF5sIEuv83k/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Music'},
#  {'_id': '7Ag2oDIeLvo',
#   'title': '1976 Buick Skyhawk Commercial',
#   'channel_title': 'OsbornTramain',
#   'category_id': 22,
#   'tags': {'split': ['$tags', '|']},
#   'views': 1749,
#   'likes': 15,
#   'dislikes': 0,
#   'comment_total': 9,
#   'thumbnail_link': 'https://i.ytimg.com/vi/7Ag2oDIeLvo/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'People & Blogs'},
#  {'_id': 'UR9k1Pjx5eg',
#   'title': 'Nicholls Postgame | Kevin Sumlin 9.9.17',
#   'channel_title': 'Texas A&M Athletics',
#   'category_id': 17,
#   'tags': {'split': ['$tags', '|']},
#   'views': 14682,
#   'likes': 44,
#   'dislikes': 50,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/UR9k1Pjx5eg/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Sports'},
#  {'_id': 'REyxoxScrbU',
# ...
#  {'_id': 'uh3aU63f8U8',
#   'title': "George Michael - Freedom '90 Music Video Outtakes",
#   'channel_title': 'georgemichaelVEVO',
#   'category_id': 10,
#   'tags': {'split': ['$tags', '|']},
#   'views': 51263,
#   'likes': 1910,
#   'dislikes': 43,
#   'comment_total': 175,
#   'thumbnail_link': 'https://i.ytimg.com/vi/uh3aU63f8U8/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Music'},
#  {'_id': 'OWpSYn40eLc',
#   'title': 'iPhone X by Pineapple | Rudy Mancuso',
#   'channel_title': 'Rudy Mancuso',
#   'category_id': 23,
#   'tags': {'split': ['$tags', '|']},
#   'views': 3771565,
#   'likes': 218508,
#   'dislikes': 5070,
#   'comment_total': 9735,
#   'thumbnail_link': 'https://i.ytimg.com/vi/OWpSYn40eLc/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Comedy'},
#  {'_id': 'pCvGBu6QXXQ',
#   'title': 'SquareTrade iPhone 8 Breakability',
#   'channel_title': 'SquareTrade, Inc.',
#   'category_id': 25,
#   'tags': {'split': ['$tags', '|']},
#   'views': 238861,
#   'likes': 140,
#   'dislikes': 81,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/pCvGBu6QXXQ/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'News & Politics'},
#  {'_id': '4WyBEMxqFaI',
#   'title': 'Flawless Fall Makeup Routine',
#   'channel_title': 'Shameless Maya',
#   'category_id': 26,
#   'tags': {'split': ['$tags', '|']},
#   'views': 21964,
#   'likes': 2356,
#   'dislikes': 37,
#   'comment_total': 284,
#   'thumbnail_link': 'https://i.ytimg.com/vi/4WyBEMxqFaI/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Howto & Style'},
#  {'_id': 'Vh2WX2JNIFo',
#   'title': 'I SLEPT WITH A GHOST. (LEGIT NOT CLICKBAIT) How My House Became Haunted',
#   'channel_title': 'MyLifeAsEva',
#   'category_id': 26,
#   'tags': {'split': ['$tags', '|']},
#   'views': 754615,
#   'likes': 49369,
#   'dislikes': 803,
#   'comment_total': 13531,
#   'thumbnail_link': 'https://i.ytimg.com/vi/Vh2WX2JNIFo/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Howto & Style'},
#  {'_id': 'jYnoFIgUwqY',
#   'title': 'GenjiSymmetraWinstonSombra Voice Lines!',
#   'channel_title': 'Hispanglosaxon',
#   'category_id': 23,
#   'tags': {'split': ['$tags', '|']},
#   'views': 203831,
#   'likes': 12379,
#   'dislikes': 79,
#   'comment_total': 1225,
#   'thumbnail_link': 'https://i.ytimg.com/vi/jYnoFIgUwqY/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Comedy'},
#  {'_id': '9EBgaxFfDA0',
#   'title': "Scratching the $1300 dollar Apple Watch - is it really 'Sapphire'?",
#   'channel_title': 'JerryRigEverything',
#   'category_id': 26,
#   'tags': {'split': ['$tags', '|']},
#   'views': 744995,
#   'likes': 24946,
#   'dislikes': 693,
#   'comment_total': 3518,
#   'thumbnail_link': 'https://i.ytimg.com/vi/9EBgaxFfDA0/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Howto & Style'},
#  {'_id': 'U69QBI6MK_A',
#   'title': "Detroit's unaffordable water hints at a U.S. crisis to come",
#   'channel_title': 'Grist',
#   'category_id': 1,
#   'tags': {'split': ['$tags', '|']},
#   'views': 2036,
#   'likes': 25,
#   'dislikes': 0,
#   'comment_total': 4,
#   'thumbnail_link': 'https://i.ytimg.com/vi/U69QBI6MK_A/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Film & Animation'},
#  {'_id': 'LHR2gzqUp5M',
#   'title': "DIY Dragon's Beard AKA Edible Hair, Corinne vs. Cooking",
#   'channel_title': 'ThreadBanger',
#   'category_id': 26,
#   'tags': {'split': ['$tags', '|']},
#   'views': 1700473,
#   'likes': 69355,
#   'dislikes': 1062,
#   'comment_total': 6059,
#   'thumbnail_link': 'https://i.ytimg.com/vi/LHR2gzqUp5M/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Howto & Style'},
#  {'_id': 'G9ADVeNpypk',
#   'title': 'Introducing Levi’s® Commuter Trucker Jacket with Jacquard by Google',
#   'channel_title': "Levi's®",
#   'category_id': 26,
#   'tags': {'split': ['$tags', '|']},
#   'views': 158649,
#   'likes': 536,
#   'dislikes': 88,
#   'comment_total': 110,
#   'thumbnail_link': 'https://i.ytimg.com/vi/G9ADVeNpypk/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Howto & Style'},
#  {'_id': 'WL3sp8BstF0',
#   'title': 'Tony Dungy on NFL protests: Players felt ‘a group of our family got attacked’',
#   'channel_title': 'US News Channel',
#   'category_id': 22,
#   'tags': {'split': ['$tags', '|']},
#   'views': 1810,
#   'likes': 1,
#   'dislikes': 3,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/WL3sp8BstF0/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'People & Blogs'},
#  {'_id': 'xMmyeKq4w8E',
#   'title': 'Dog Accidentally Pushes Owner off Boat',
#   'channel_title': 'DailyPicksandFlicks',
#   'category_id': 23,
#   'tags': {'split': ['$tags', '|']},
#   'views': 8886,
#   'likes': 82,
#   'dislikes': 2,
#   'comment_total': 15,
#   'thumbnail_link': 'https://i.ytimg.com/vi/xMmyeKq4w8E/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Comedy'},
#  {'_id': 'l7yxJDFvTRM',
#   'title': 'Trying to play Game Boy',
#   'channel_title': 'Chris Cohoon',
#   'category_id': 22,
#   'tags': {'split': ['$tags', '|']},
#   'views': 2694212,
#   'likes': 37659,
#   'dislikes': 3072,
#   'comment_total': 7207,
#   'thumbnail_link': 'https://i.ytimg.com/vi/l7yxJDFvTRM/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'People & Blogs'},
#  {'_id': 'IqLUd_FVZgk',
#   'title': 'WATCH LIVE: Sarah Sanders holds White House news briefing',
#   'channel_title': 'PBS NewsHour',
#   'category_id': 25,
#   'tags': {'split': ['$tags', '|']},
#   'views': 19254,
#   'likes': 86,
#   'dislikes': 80,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/IqLUd_FVZgk/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'News & Politics'},
#  {'_id': '7wwTAo01AKs',
#   'title': "Jesse Williams Calls Pregame National Anthem 'A Scam' Convincing Americans 'To Go Overseas and Kill'",
#   'channel_title': 'Fan Dick',
#   'category_id': 25,
#   'tags': {'split': ['$tags', '|']},
#   'views': 58396,
#   'likes': 300,
#   'dislikes': 508,
#   'comment_total': 338,
#   'thumbnail_link': 'https://i.ytimg.com/vi/7wwTAo01AKs/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'News & Politics'},
#  {'_id': 'P00HMxdsVZI',
#   'title': 'Lizzo - Truth Hurts [Official Video]',
#   'channel_title': 'Lizzo Music',
#   'category_id': 10,
#   'tags': {'split': ['$tags', '|']},
#   'views': 64963,
#   'likes': 3036,
#   'dislikes': 61,
#   'comment_total': 245,
#   'thumbnail_link': 'https://i.ytimg.com/vi/P00HMxdsVZI/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Music'},
#  {'_id': 'BDw7rRaZ6GM',
#   'title': 'That Moment You Realize Your Dad is Dying',
#   'channel_title': 'SoulPancake',
#   'category_id': 24,
#   'tags': {'split': ['$tags', '|']},
#   'views': 16825,
#   'likes': 895,
#   'dislikes': 11,
#   'comment_total': 89,
#   'thumbnail_link': 'https://i.ytimg.com/vi/BDw7rRaZ6GM/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Entertainment'},
#  {'_id': 'VFODNI4DBDI',
#   'title': 'I Made A Mistake',
#   'channel_title': 'Courageous Conservatives PAC',
#   'category_id': 25,
#   'tags': {'split': ['$tags', '|']},
#   'views': 318780,
#   'likes': 1228,
#   'dislikes': 4501,
#   'comment_total': 1363,
#   'thumbnail_link': 'https://i.ytimg.com/vi/VFODNI4DBDI/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'News & Politics'},
#  {'_id': 'tY0RWL9k1T8',
#   'title': 'Boeing Sponsors GoFly',
#   'channel_title': 'Boeing',
#   'category_id': 28,
#   'tags': {'split': ['$tags', '|']},
#   'views': 18220,
#   'likes': 418,
#   'dislikes': 13,
#   'comment_total': 44,
#   'thumbnail_link': 'https://i.ytimg.com/vi/tY0RWL9k1T8/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Science & Technology'},
#  {'_id': '2jtDZXbN-_c',
#   'title': 'What if Everyone Ate Beans Instead of Beef?',
#   'channel_title': 'The Atlantic',
#   'category_id': 22,
#   'tags': {'split': ['$tags', '|']},
#   'views': 27916,
#   'likes': 364,
#   'dislikes': 22,
#   'comment_total': 93,
#   'thumbnail_link': 'https://i.ytimg.com/vi/2jtDZXbN-_c/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'People & Blogs'},
#  {'_id': 'WvkrRBduZ84',
#   'title': 'Derrick Rose Press Conference',
#   'channel_title': 'NBA',
#   'category_id': 1,
#   'tags': {'split': ['$tags', '|']},
#   'views': 43947,
#   'likes': 348,
#   'dislikes': 29,
#   'comment_total': 166,
#   'thumbnail_link': 'https://i.ytimg.com/vi/WvkrRBduZ84/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Film & Animation'},
#  {'_id': 'ouJwpthMfkY',
#   'title': 'Drugstore/Affordable Fall Makeup Tutorial | Jaclyn Hill',
#   'channel_title': 'Jaclyn Hill',
#   'category_id': 26,
#   'tags': {'split': ['$tags', '|']},
#   'views': 948523,
#   'likes': 55513,
#   'dislikes': 1998,
#   'comment_total': 7267,
#   'thumbnail_link': 'https://i.ytimg.com/vi/ouJwpthMfkY/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Howto & Style'},
#  {'_id': 'mrTHfBCduRA',
#   'title': 'Thalidomide: The Chemistry Mistake That Killed Thousands of Babies',
#   'channel_title': 'SciShow',
#   'category_id': 27,
#   'tags': {'split': ['$tags', '|']},
#   'views': 361114,
#   'likes': 12214,
#   'dislikes': 155,
#   'comment_total': 851,
#   'thumbnail_link': 'https://i.ytimg.com/vi/mrTHfBCduRA/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Education'},
#  {'_id': 'oStLD-yYAy0',
#   'title': 'Crowdfunding, explained by Exploding Kittens',
#   'channel_title': 'Vox',
#   'category_id': 25,
#   'tags': {'split': ['$tags', '|']},
#   'views': 292572,
#   'likes': 8571,
#   'dislikes': 411,
#   'comment_total': 568,
#   'thumbnail_link': 'https://i.ytimg.com/vi/oStLD-yYAy0/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'News & Politics'},
#  {'_id': 'zuUQDdWNAPc',
#   'title': "SNL Host Ryan Gosling's Triumphant Return",
#   'channel_title': 'Saturday Night Live',
#   'category_id': 24,
#   'tags': {'split': ['$tags', '|']},
#   'views': 336397,
#   'likes': 4185,
#   'dislikes': 138,
#   'comment_total': 231,
#   'thumbnail_link': 'https://i.ytimg.com/vi/zuUQDdWNAPc/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Entertainment'},
#  {'_id': 'Itd_DFAw8OE',
#   'title': 'DIY EDIBLE GEODE - 6 MONTHS TO GROW!!',
#   'channel_title': 'HellthyJunkFood',
#   'category_id': 24,
#   'tags': {'split': ['$tags', '|']},
#   'views': 306292,
#   'likes': 9801,
#   'dislikes': 360,
#   'comment_total': 1308,
#   'thumbnail_link': 'https://i.ytimg.com/vi/Itd_DFAw8OE/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Entertainment'},
#  {'_id': 'YF6dNlhXaJ0',
#   'title': 'New Kardashian Babies = New Kardashian Show',
#   'channel_title': 'Jimmy Kimmel Live',
#   'category_id': 24,
#   'tags': {'split': ['$tags', '|']},
#   'views': 279743,
#   'likes': 3913,
#   'dislikes': 232,
#   'comment_total': 301,
#   'thumbnail_link': 'https://i.ytimg.com/vi/YF6dNlhXaJ0/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Entertainment'},
#  {'_id': '81OBIsQoQIc',
#   'title': '한국 치맥을 처음 먹어본 킹스맨 배우들의 반응!?',
#   'channel_title': '영국남자 Korean Englishman',
#   'category_id': 23,
#   'tags': {'split': ['$tags', '|']},
#   'views': 2340640,
#   'likes': 63881,
#   'dislikes': 619,
#   'comment_total': 7424,
#   'thumbnail_link': 'https://i.ytimg.com/vi/81OBIsQoQIc/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Comedy'},
#  {'_id': 's3Hk_lDw5yo',
#   'title': 'Demi Lovato - Cry Baby (Audio Snippet)',
#   'channel_title': 'DemiLovatoVEVO',
#   'category_id': 10,
#   'tags': {'split': ['$tags', '|']},
#   'views': 98963,
#   'likes': 9676,
#   'dislikes': 115,
#   'comment_total': 661,
#   'thumbnail_link': 'https://i.ytimg.com/vi/s3Hk_lDw5yo/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Music'},
#  {'_id': 'UVwLjEK0jio',
#   'title': 'Gomes leads Indians to 4-2 victory: 9/27/17',
#   'channel_title': 'MLB',
#   'category_id': 17,
#   'tags': {'split': ['$tags', '|']},
#   'views': 17107,
#   'likes': 110,
#   'dislikes': 23,
#   'comment_total': 67,
#   'thumbnail_link': 'https://i.ytimg.com/vi/UVwLjEK0jio/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Sports'},
#  {'_id': '9yqdwbJZtSc',
#   'title': 'Lorde - Green Light in the Live Lounge',
#   'channel_title': 'BBCRadio1VEVO',
#   'category_id': 10,
#   'tags': {'split': ['$tags', '|']},
#   'views': 73140,
#   'likes': 3626,
#   'dislikes': 36,
#   'comment_total': 190,
#   'thumbnail_link': 'https://i.ytimg.com/vi/9yqdwbJZtSc/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Music'},
#  {'_id': 'c0FjpqLfGN8',
#   'title': "Why New Yorkers don't pay contractors.",
#   'channel_title': 'Louis Rossmann',
#   'category_id': 27,
#   'tags': {'split': ['$tags', '|']},
#   'views': 253745,
#   'likes': 2828,
#   'dislikes': 112,
#   'comment_total': 409,
#   'thumbnail_link': 'https://i.ytimg.com/vi/c0FjpqLfGN8/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Education'},
#  {'_id': 'z8N40PtsEw4',
#   'title': 'Cardi B Explains How NYPD Put Her In A Chokehold *Explicit Language Warning*',
#   'channel_title': 'WEDR 99 JAMZ',
#   'category_id': 24,
#   'tags': {'split': ['$tags', '|']},
#   'views': 11417,
#   'likes': 21,
#   'dislikes': 2,
#   'comment_total': 16,
#   'thumbnail_link': 'https://i.ytimg.com/vi/z8N40PtsEw4/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Entertainment'},
#  {'_id': 'ZYSjPZUqLdk',
#   'title': "Trump and Russia: An Introduction to What We Know (and What We Don't)",
#   'channel_title': 'vlogbrothers',
#   'category_id': 22,
#   'tags': {'split': ['$tags', '|']},
#   'views': 313038,
#   'likes': 16494,
#   'dislikes': 2248,
#   'comment_total': 2638,
#   'thumbnail_link': 'https://i.ytimg.com/vi/ZYSjPZUqLdk/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'People & Blogs'},
#  {'_id': 'GDIOfv643TM',
#   'title': 'Are you basic? (YIAY #360)',
#   'channel_title': 'jacksfilms',
#   'category_id': 23,
#   'tags': {'split': ['$tags', '|']},
#   'views': 1270345,
#   'likes': 70827,
#   'dislikes': 695,
#   'comment_total': 6036,
#   'thumbnail_link': 'https://i.ytimg.com/vi/GDIOfv643TM/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Comedy'},
#  {'_id': 'o0Ddl1DI-go',
#   'title': 'GRWM In The Shower! Styling My Natural Hair! | Jackie Aina',
#   'channel_title': 'Jackie Aina',
#   'category_id': 26,
#   'tags': {'split': ['$tags', '|']},
#   'views': 372733,
#   'likes': 30076,
#   'dislikes': 355,
#   'comment_total': 3985,
#   'thumbnail_link': 'https://i.ytimg.com/vi/o0Ddl1DI-go/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Howto & Style'},
#  {'_id': 'E6PU9IvLJM0',
#   'title': 'Bobby Roode calls out Dolph Ziggler: SmackDown LIVE, Sept. 26, 2017',
#   'channel_title': 'WWE',
#   'category_id': 17,
#   'tags': {'split': ['$tags', '|']},
#   'views': 888714,
#   'likes': 17115,
#   'dislikes': 838,
#   'comment_total': 2417,
#   'thumbnail_link': 'https://i.ytimg.com/vi/E6PU9IvLJM0/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Sports'},
#  {'_id': 'SNGWh_-R1VE',
#   'title': 'This is Star Wars Battlefront 2',
#   'channel_title': 'EA Star Wars',
#   'category_id': 20,
#   'tags': {'split': ['$tags', '|']},
#   'views': 3384577,
#   'likes': 121972,
#   'dislikes': 3291,
#   'comment_total': 23436,
#   'thumbnail_link': 'https://i.ytimg.com/vi/SNGWh_-R1VE/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Gaming'},
#  {'_id': 'MFoODeZfSD0',
#   'title': 'Can a Laser Cook Potato Chips?',
#   'channel_title': 'William Osman',
#   'category_id': 28,
#   'tags': {'split': ['$tags', '|']},
#   'views': 601410,
#   'likes': 11390,
#   'dislikes': 1420,
#   'comment_total': 2043,
#   'thumbnail_link': 'https://i.ytimg.com/vi/MFoODeZfSD0/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Science & Technology'},
#  ...]

# %% [markdown]
# ## Question 4

# %%
cur = collection.find().sort("views",-1).limit(3)
list(cur)
# Out:
# [{'_id': 'MBdVXkSdhwU',
#   'title': "BTS (방탄소년단) 'DNA' Official MV",
#   'channel_title': 'ibighit',
#   'category_id': 10,
#   'tags': 'BIGHIT|빅히트|방탄소년단|BTS|BANGTAN|방탄',
#   'views': 41500672,
#   'likes': 2010366,
#   'dislikes': 78076,
#   'comment_total': 736179,
#   'thumbnail_link': 'https://i.ytimg.com/vi/MBdVXkSdhwU/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Music'},
#  {'_id': 'tt2k8PGm-TI',
#   'title': 'ZAYN - Dusk Till Dawn ft. Sia',
#   'channel_title': 'ZaynVEVO',
#   'category_id': 10,
#   'tags': 'Dusk Till Dawn|Pop|RCA Records Label|ZAYN feat. Sia',
#   'views': 36323498,
#   'likes': 1431683,
#   'dislikes': 28049,
#   'comment_total': 100661,
#   'thumbnail_link': 'https://i.ytimg.com/vi/tt2k8PGm-TI/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Music'},
#  {'_id': 'LunHybOKIjU',
#   'title': 'Eminem Rips Donald Trump In BET Hip Hop Awards Freestyle Cypher',
#   'channel_title': 'BETNetworks',
#   'category_id': 24,
#   'tags': 'BET|BET Networks|BET Music|Black Entertainment Television|eminem|freestyle|full|hip hop awards|hip hop awards 2017|bet hip hop awards|donald trump|potus|full freestyle|EMINEM TRUMP|TRUMP TWITTER|trump tweet|trump nfl|eminem bet cypher|bet cypher|eminem freestyle|8 mile|eminem new album|trump diss|eminem trump diss',
#   'views': 33191594,
#   'likes': 982842,
#   'dislikes': 184310,
#   'comment_total': 337603,
#   'thumbnail_link': 'https://i.ytimg.com/vi/LunHybOKIjU/default.jpg',
#   'date': datetime.datetime(1970, 1, 1, 0, 0),
#   'category_name': 'Entertainment'}]

# %% [markdown]
# ## Question 5

# %%
cur = collection.aggregate([
    {"$group":{"_id":"$category_name","nb":{"$avg":"$views"}}}
])
list(cur)
# Out:
# [{'_id': 'Film & Animation', 'nb': 966547.2871287129},
#  {'_id': 'Gaming', 'nb': 777213.0357142857},
#  {'_id': 'News & Politics', 'nb': 533575.1262626263},
#  {'_id': 'Howto & Style', 'nb': 556002.6679389313},
#  {'_id': 'Comedy', 'nb': 1317200.7289719626},
#  {'_id': 'Nonprofits & Activism', 'nb': 681178.2},
#  {'_id': 'People & Blogs', 'nb': 892992.28515625},
#  {'_id': 'Shows', 'nb': 8726.0},
#  {'_id': 'Travel & Events', 'nb': 426492.22222222225},
#  {'_id': 'Science & Technology', 'nb': 861563.6158940397},
#  {'_id': 'Entertainment', 'nb': 1059427.7735849055},
#  {'_id': 'Education', 'nb': 550585.2659574468},
#  {'_id': 'Sports', 'nb': 618074.711409396},
#  {'_id': 'Pets & Animals', 'nb': 633906.4210526316},
#  {'_id': 'Music', 'nb': 1442240.943283582},
#  {'_id': 'Autos & Vehicles', 'nb': 622727.8648648649}]

# %% [markdown]
# ## Question 6

# %%
cur = collection.aggregate([
    {"$group":{"_id":"$channel_title","likes":{"$avg":"$likes"}}},
    {"$sort":{"likes":-1}},
    {"$limit":3}
])
list(cur)
# Out:
# [{'_id': 'ibighit', 'likes': 1533457.0},
#  {'_id': 'ZaynVEVO', 'likes': 1431683.0},
#  {'_id': 'BETNetworks', 'likes': 982842.0}]
